# %% [markdown]
# <a href="https://colab.research.google.com/github/20020109tharindu/ML_Final_Project/blob/svm/models/preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mount Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content
# Out:
# /content

# %%
# Clone GitHub repo
# !git clone https://github.com/20020109tharindu/ML_Final_Project.git
# %cd ML_Final_Project
# Out:
# Cloning into 'ML_Final_Project'...
# remote: Enumerating objects: 51, done.
# remote: Counting objects: 100% (51/51), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 51 (delta 21), reused 31 (delta 8), pack-reused 0 (from 0)
# Receiving objects: 100% (51/51), 118.07 KiB | 1.57 MiB/s, done.
# Resolving deltas: 100% (21/21), done.
# /content/ML_Final_Project

# %%
#  Install libraries
# !pip install imbalanced-learn -q

# %%
#  Run preprocessing and save splits
import sys
sys.path.append('/content/ML_Final_Project/preprocessing')

# %%
from fraud_preprocessing import preprocess, save_splits

# %%
X_train, X_test, y_train, y_test = preprocess(
    filepath='/content/drive/MyDrive/FraudDetection/dataset/creditcard.csv'
)
# Out:
# ...
# DATASET OVERVIEW
# ...
# Shape            : (284807, 31)
# Missing values   : 0
#
# Class distribution:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64
#
# Fraud percentage : 0.1727%
# ...
# /content/ML_Final_Project/preprocessing/fraud_preprocessing.py:143: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=labels, y=counts.values, palette=["steelblue", "crimson"])
# ✔ Saved → ../results/plots/class_distribution.png
# ✔ Saved → ../results/plots/amount_distribution.png
# ✔ Saved → ../results/plots/correlation_heatmap.png
# ✔ 'Amount' and 'Time' scaled → 'scaled_amount', 'scaled_time'
#
# ✔ Train size     : 227,845 samples
# ✔ Test size      : 56,962 samples
# ✔ Fraud in train : 394 (0.173%)
# ✔ Fraud in test  : 98 (0.172%)
#
# ── Before SMOTE ──
# Class
# 0    227451
# 1       394
# Name: count, dtype: int64
#
# ...

# %%
save_splits(
    X_train, X_test, y_train, y_test,
    output_dir='/content/drive/MyDrive/FraudDetection/cleaned_data'
)
# Out:
# ✅ Splits saved to '/content/drive/MyDrive/FraudDetection/cleaned_data/'
#    X_train.csv : (454902, 30)
#    X_test.csv  : (56962, 30)
#    y_train.csv : (454902,)
#    y_test.csv  : (56962,)
#
# 👉 Upload the cleaned_data/ folder to Google Drive and share with teammates!
